# %%
import cv2
import pywt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pickle
from scipy import stats as stats
from skimage import feature
from skimage.feature import greycoprops,greycomatrix
import os
import skimage.measure
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten,Activation
from keras import layers
import tensorflow as tf

# %%
def feature_extractor(dataset):
    rowsList=[]
    for image in range(dataset.shape[0]):
        rows=[]
        img = dataset[image]  
        coeffs=pywt.wavedec(img, 'db1',level=1)
        cA=coeffs[0]
        cA = cA / cA.max()
        cA = 255 * cA 
        cA=cA.astype(np.uint8)
#         for angs in angles:
        g=greycomatrix(cA,[1],[0],normed=True)
#             temp=[np.mean(greycoprops(g, 'contrast')),np.mean(greycoprops(g, 'dissimilarity')),np.mean(greycoprops(g, 'correlation'))]
        temp=[np.mean(greycoprops(g, 'energy')),skimage.measure.shannon_entropy(g),np.mean(greycoprops(g, 'contrast')),np.mean(greycoprops(g, 'dissimilarity')),np.mean(greycoprops(g, 'homogeneity')),np.mean(greycoprops(g, 'correlation')),np.mean(greycoprops(g, 'ASM'))]
        rows.append(temp)
        rowsList.append(rows)
    return np.array(rowsList)

# %%
pickle_in = open("X_train","rb")
X_train = feature_extractor(pickle.load(pickle_in))
pickle_in = open("y_train","rb")
y_train = pickle.load(pickle_in)

# %%
pickle_in = open("X_test","rb")
X_test = feature_extractor(pickle.load(pickle_in))
pickle_in = open("y_test","rb")
y_test = pickle.load(pickle_in)

# %%
X_train = X_train.reshape(-1,1,7, 1)
X_test = X_test.reshape(-1,1,7, 1)

# %%
model = Sequential()
model.add(layers.Conv2D(32, (1,1), activation='relu', input_shape=(1,7,1),))
model.add(layers.MaxPooling2D((1,1)))
model.add(layers.Conv2D(64, (1,1), activation='relu'))
model.add(layers.MaxPooling2D((1,1)))
model.add(layers.Conv2D(64, (1,1), activation='relu'))

model.summary()

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(3))
model.add(Activation('sigmoid'))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 1, 7, 32)          64
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 1, 7, 32)          0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 1, 7, 64)          2112
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 1, 7, 64)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 7, 64)          4160
# =================================================================
# Total params: 6,336
# Trainable params: 6,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
class MyThresholdCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(MyThresholdCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None): 
        val_acc = logs["val_accuracy"]
        if val_acc >= self.threshold:
            self.model.stop_training = True

# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
# callback = MyThresholdCallback(threshold=0.8)
history = model.fit(X_train, y_train, epochs=100,validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 695ms/step - loss: 35.6018 - accuracy: 0.3333 - val_loss: 16.1245 - val_accuracy: 0.3333
# Epoch 2/100
# 1/1 [==============================] - 0s 43ms/step - loss: 15.7715 - accuracy: 0.3333 - val_loss: 1.9222 - val_accuracy: 0.4167
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4047 - accuracy: 0.3333 - val_loss: 1.1798 - val_accuracy: 0.3333
# Epoch 4/100
# 1/1 [==============================] - 0s 49ms/step - loss: 2.1883 - accuracy: 0.3333 - val_loss: 3.8782 - val_accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 44ms/step - loss: 6.7734 - accuracy: 0.3333 - val_loss: 3.6952 - val_accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 4.7441 - accuracy: 0.3333 - val_loss: 6.3602 - val_accuracy: 0.3333
# Epoch 7/100
# 1/1 [==============================] - 0s 43ms/step - loss: 6.5340 - accuracy: 0.3333 - val_loss: 7.4888 - val_accuracy: 0.3333
# Epoch 8/100
# 1/1 [==============================] - 0s 45ms/step - loss: 7.3319 - accuracy: 0.3333 - val_loss: 7.4280 - val_accuracy: 0.3333
# Epoch 9/100
# 1/1 [==============================] - 0s
100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8503 - accuracy: 0.5333 - val_loss: 1.4418 - val_accuracy: 0.2500
# Epoch 37/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9819 - accuracy: 0.4667 - val_loss: 1.5176 - val_accuracy: 0.2500
# Epoch 38/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0147 - accuracy: 0.4667 - val_loss: 1.3336 - val_accuracy: 0.2500
# Epoch 39/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9322 - accuracy: 0.5000 - val_loss: 1.0149 - val_accuracy: 0.4167
# Epoch 40/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8154 - accuracy: 0.5333 - val_loss: 0.8359 - val_accuracy: 0.5000
# Epoch 41/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8126 - accuracy: 0.6000 - val_loss: 0.9169 - val_accuracy: 0.5000
# Epoch 42/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8907 - accuracy: 0.5667 - val_loss: 1.0027 - val_accuracy: 0.5000
# Epoch 43/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7606 - accuracy: 0.6000 - val_loss: 1.3055 - val_accuracy: 0.2500
# Epoch 44/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8143 - accuracy: 0.4667 - val_loss: 1.5079 - val_accuracy: 0.2500
# Epoch 45/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8734 - accuracy: 0.4333 - val_loss: 1.5230 - val_accuracy: 0.2500
# Epoch 46/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8762 - accuracy: 0.4333 - val_loss: 1.3586 - val_accuracy: 0.2500
# Epoch 47/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8221 - accuracy: 0.4667 - val_loss: 1.0913 - val_accuracy: 0.3333
# Epoch 48/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7562 - accuracy: 0.5333 - val_loss: 0.8842 - val_accuracy: 0.5000
# Epoch 49/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7589 - accuracy: 0.6000 - val_loss: 0.8566 - val_accuracy: 0.5000
# Epoch 50/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8271 - accuracy: 0.5667 - val_loss: 0.8516 - val_accuracy: 0.5000
# Epoch 51/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7612 - accuracy: 0.6000 - val_loss: 0.9963 - val_accuracy: 0.5000
# Epoch 52/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7522 - accuracy: 0.5667 - val_loss: 1.1508 - val_accuracy: 0.3333
# Epoch 53/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7776 - accuracy: 0.5667 - val_loss: 1.1992 - val_accuracy: 0.3333
# Epoch 54/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7826 - accuracy: 0.5667 - val_loss: 1.1251 - val_accuracy: 0.3333
# Epoch 55/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.7561 - accuracy: 0.5333 - val_loss: 0.9887 - val_accuracy: 0.5000
# Epoch 56/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.7276 - accuracy: 0.5667 - val_loss: 0.8926 - val_accuracy: 0.5000
# Epoch 57/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7351 - accuracy: 0.6000 - val_loss: 0.8766 - val_accuracy: 0.4167
# Epoch 58/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7582 - accuracy: 0.6000 - val_loss: 0.8832 - val_accuracy: 0.5000
# Epoch 59/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7306 - accuracy: 0.6000 - val_loss: 0.9541 - val_accuracy: 0.5000
# Epoch 60/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7156 - accuracy: 0.5667 - val_loss: 1.0321 - val_accuracy: 0.3333
# Epoch 61/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7250 - accuracy: 0.5667 - val_loss: 1.0368 - val_accuracy: 0.4167
# Epoch 62/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7276 - accuracy: 0.5667 - val_loss: 0.9520 - val_accuracy: 0.5000
# Epoch 63/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7142 - accuracy: 0.5667 - val_loss: 0.8334 - val_accuracy: 0.5000
# Epoch 64/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7058 - accuracy: 0.5667 - val_loss: 0.7775 - val_accuracy: 0.5833
# Epoch 65/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7134 - accuracy: 0.6000 - val_loss: 0.7950 - val_accuracy: 0.6667
# Epoch 66/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7012 - accuracy: 0.6000 - val_loss: 0.8638 - val_accuracy: 0.6667
# Epoch 67/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6922 - accuracy: 0.5667 - val_loss: 0.9299 - val_accuracy: 0.6667
# Epoch 68/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6971 - accuracy: 0.7000 - val_loss: 0.9351 - val_accuracy: 0.5833
# Epoch 69/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6971 - accuracy: 0.6000 - val_loss: 0.8774 - val_accuracy: 0.7500
# Epoch 70/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6884 - accuracy: 0.6333 - val_loss: 0.8031 - val_accuracy: 0.7500
# Epoch 71/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6840 - accuracy: 0.6333 - val_loss: 0.7612 - val_accuracy: 0.7500
# Epoch 72/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6862 - accuracy: 0.6333 - val_loss: 0.7609 - val_accuracy: 0.7500
# Epoch 73/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6799 - accuracy: 0.6667 - val_loss: 0.7953 - val_accuracy: 0.8333
# Epoch 74/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6754 - accuracy: 0.6333 - val_loss: 0.8292 - val_accuracy: 0.8333
# Epoch 75/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6771 - accuracy: 0.6667 - val_loss: 0.8248 - val_accuracy: 0.8333
# Epoch 76/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6759 - accuracy: 0.6333 - val_loss: 0.7822 - val_accuracy: 0.8333
# Epoch 77/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6707 - accuracy: 0.6333 - val_loss: 0.7351 - val_accuracy: 0.8333
# Epoch 78/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6687 - accuracy: 0.7000 - val_loss: 0.7142 - val_accuracy: 0.8333
# Epoch 79/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6693 - accuracy: 0.7000 - val_loss: 0.7242 - val_accuracy: 0.8333
# Epoch 80/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6659 - accuracy: 0.7000 - val_loss: 0.7543 - val_accuracy: 0.8333
# Epoch 81/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6640 - accuracy: 0.7000 - val_loss: 0.7769 - val_accuracy: 0.8333
# Epoch 82/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6649 - accuracy: 0.7000 - val_loss: 0.7686 - val_accuracy: 0.8333
# Epoch 83/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6636 - accuracy: 0.7000 - val_loss: 0.7356 - val_accuracy: 0.8333
# Epoch 84/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6608 - accuracy: 0.7333 - val_loss: 0.7043 - val_accuracy: 0.8333
# Epoch 85/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6604 - accuracy: 0.7000 - val_loss: 0.6933 - val_accuracy: 0.8333
# Epoch 86/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6599 - accuracy: 0.6667 - val_loss: 0.7044 - val_accuracy: 0.8333
# Epoch 87/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6577 - accuracy: 0.7000 - val_loss: 0.7260 - val_accuracy: 0.8333
# Epoch 88/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6570 - accuracy: 0.7333 - val_loss: 0.7374 - val_accuracy: 0.8333
# Epoch 89/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6569 - accuracy: 0.7000 - val_loss: 0.7276 - val_accuracy: 0.8333
# Epoch 90/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6553 - accuracy: 0.7333 - val_loss: 0.7060 - val_accuracy: 0.8333
# Epoch 91/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6537 - accuracy: 0.7333 - val_loss: 0.6909 - val_accuracy: 0.8333
# Epoch 92/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6531 - accuracy: 0.7000 - val_loss: 0.6920 - val_accuracy: 0.8333
# Epoch 93/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6519 - accuracy: 0.7333 - val_loss: 0.7074 - val_accuracy: 0.8333
# Epoch 94/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6502 - accuracy: 0.7667 - val_loss: 0.7257 - val_accuracy: 0.8333
# Epoch 95/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6493 - accuracy: 0.7667 - val_loss: 0.7328 - val_accuracy: 0.8333
# Epoch 96/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6484 - accuracy: 0.7333 - val_loss: 0.7242 - val_accuracy: 0.8333
# Epoch 97/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6467 - accuracy: 0.7667 - val_loss: 0.7107 - val_accuracy: 0.8333
# Epoch 98/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6453 - accuracy: 0.7667 - val_loss: 0.7043 - val_accuracy: 0.8333
# Epoch 99/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6443 - accuracy: 0.7333 - val_loss: 0.7100 - val_accuracy: 0.8333
# Epoch 100/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6428 - accuracy: 0.7333 - val_loss: 0.7244 - val_accuracy: 0.8333

# %%
model.save('model.h5')
